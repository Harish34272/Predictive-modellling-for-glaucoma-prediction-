# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation , Add , Input
from scipy.signal.windows import gaussian
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
from keras.callbacks import ModelCheckpoint
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
# Out:
# WARNING:tensorflow:From E:\study material\miniproject-2\GalacticGrove\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img_height = 224
img_width = 224
batch_size = 32

# %%
img_height = 224
img_width = 224
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
)

base_dirs = {
    'train': r'datasets/real_combined_last_dataset/train',
    'test': r'datasets/real_combined_last_dataset/test'
}

# %%
def data_generator(directory):
    return datagen.flow_from_directory(
        directory,
        target_size=(img_height, img_width),
        batch_size=32,
        class_mode='binary',  # Update to 'categorical' for classification or 'input' for segmentation
        shuffle=False,  # Set to True if you want to shuffle the data
        seed=42
    )

train_ds = data_generator(base_dirs['train'])
test_ds = data_generator(base_dirs['test'])
# Out:
# Found 6359 images belonging to 3 classes.
# Found 818 images belonging to 3 classes.

# %%
def preprocess_image(image_path, target_size=(224, 224)):
    image = cv2.imread(image_path)

    # Apply Gaussian smoothing
    image = cv2.GaussianBlur(image, (5, 5), 0)

    # Split the image into B,G,R channels
    B, G, R = cv2.split(image)

    # Apply histogram equalization to each channel
    B_equ = cv2.equalizeHist(B)
    G_equ = cv2.equalizeHist(G)
    R_equ = cv2.equalizeHist(R)

    # Merge the channels back together
    equ = cv2.merge((B_equ, G_equ, R_equ))

    # Resize the image
    equ = cv2.resize(equ, target_size)

    # Normalize pixel values
    equ = equ / 255.0

    return equ

# %%
def segment(image, plot_seg, plot_hist):
    output_directory = 'datasets/real_combined_last_dataset/Cups_discs1'
    # Pre-processing and Smoothing
    image = image.astype('uint8')
    Abo, Ago, Aro = cv2.split(image)
    Aro = clahe.apply(Aro)
    Ago = Ago.astype('uint8')
    Ago = clahe.apply(Ago)
    # Gaussian Window for smoothing
    M = 60
    filter = gaussian(M, std=6)
    filter = filter / sum(filter)
    STDf = filter.std()

    # Preprocessing Red and Green Channels
    Ar = Aro - Aro.mean() - Aro.std()
    Mr = Ar.mean()
    SDr = Ar.std()
    #print("Mean Ar:", Ar.mean())
    #print("Std Dev Ar:", Ar.std())
    Thr = Ar.mean() - 0.5 * Ar.std()  # Adjust as needed
    #Thr = 0.5 * M - STDf - Ar.std()
    #print("THR",Thr)
    Ag = Ago - Ago.mean() - Ago.std()
    Mg = Ag.mean()
    SDg = Ag.std()
    Thg = 0.5 * Mg + 2 * STDf + 2 * SDg + Mg
    #print("Thg",Thg)
    # Histogram Calculation
    hist, bins = np.histogram(Ag.ravel(), 256, [0, 256])
    histr, binsr = np.histogram(Ar.ravel(), 256, [0, 256])

    # Histogram Smoothing
    smooth_hist_g = np.convolve(filter, hist)
    smooth_hist_r = np.convolve(filter, histr)

    if plot_hist:
        plt.subplot(2, 2, 1)
        plt.plot(hist)
        plt.title("Preprocessed Green Channel")
        plt.subplot(2, 2, 2)
        plt.plot(smooth_hist_g)
        plt.title("Smoothed Histogram Green Channel")
        plt.subplot(2, 2, 3)
        plt.plot(histr)
        plt.title("Preprocessed Red Channel")
        plt.subplot(2, 2, 4)
        plt.plot(smooth_hist_r)
        plt.title("Smoothed Histogram Red Channel")
        plt.show()
    Ar = Ar.astype('uint8')
    Ag = Ag.astype('uint8')
    # Binary decision maps for Optic Disk and Optic Cup
    _, Dd = cv2.threshold(Ar, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    _, Dc = cv2.threshold(Ag, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    os.makedirs(output_directory, exist_ok=True)
    cv2.imwrite(os.path.join(output_directory, 'disk.png'), Dd)
    plt.imsave(os.path.join(output_directory, 'cup.png'), Dc)

    if plot_seg:
        plt.subplot(2, 2, 1)
        plt.imshow(Dd, cmap='gray')
        plt.axis("off")
        plt.title("Optic Disk")
        plt.subplot(2, 2, 2)
        plt.imshow(Dc, cmap='gray')
        plt.axis("off")
        plt.title("Optic Cup")
        plt.show()


    return Dd, Dc

# %%
def cdr(cup, disc, plot):
    # Convert cup and disc images to uint8 type
    cup = cup.astype('uint8')
    disc = disc.astype('uint8')

    # Morphological operations on cup
    R1 = cv2.morphologyEx(cup, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(2,2)), iterations = 1)
    r1 = cv2.morphologyEx(R1, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(7,7)), iterations = 1)
    R2 = cv2.morphologyEx(r1, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(1,21)), iterations = 1)
    r2 = cv2.morphologyEx(R2, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(21,1)), iterations = 1)
    R3 = cv2.morphologyEx(r2, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(33,33)), iterations = 1)
    r3 = cv2.morphologyEx(R3, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(43,43)), iterations = 1)

    img = clahe.apply(r3)

    # Find contours in cup
    ret, thresh = cv2.threshold(cup, 127, 255, 0)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cup_diameter = 0

    if contours:
        largest_area = 0
        el_cup = contours[0]
        for i in range(len(contours)):
            if len(contours[i]) >= 5:
                area = cv2.contourArea(contours[i])
                if area > largest_area:
                    largest_area = area
                    el_cup = cv2.fitEllipse(contours[i])

        cv2.ellipse(img, el_cup, (140, 60, 150), 3)
        x, y, w, h = cv2.boundingRect(contours[0])
        cup_diameter = max(w, h)

    # Morphological operations on disc
    R1 = cv2.morphologyEx(disc, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(2,2)), iterations = 1)
    r1 = cv2.morphologyEx(R1, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(7,7)), iterations = 1)
    R2 = cv2.morphologyEx(r1, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(1,21)), iterations = 1)
    r2 = cv2.morphologyEx(R2, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(21,1)), iterations = 1)
    R3 = cv2.morphologyEx(r2, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(33,33)), iterations = 1)
    r3 = cv2.morphologyEx(R3, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(43,43)), iterations = 1)

    img2 = clahe.apply(r3)

    # Find contours in disc
    ret, thresh = cv2.threshold(disc, 127, 255, 0)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    disk_diameter = 0

    if contours:
        largest_area = 0
        el_disc = contours[0]
        for i in range(len(contours)):
            if len(contours[i]) >= 5:
                area = cv2.contourArea(contours[i])
                if area > largest_area:
                    largest_area = area
                    el_disc = cv2.fitEllipse(contours[i])

        cv2.ellipse(img2, el_disc, (140, 60, 150), 3)
        x, y, w, h = cv2.boundingRect(contours[0])
        disk_diameter = max(w, h)


    if plot:
        plt.subplot(2,2,1)
        plt.imshow(img2, interpolation='bicubic')
        plt.axis("off")
        plt.title("Optic Disk ")
        plt.subplot(2,2,2)
        plt.imshow(img)
        plt.axis("off")
        plt.title("Optic Cup ")
        plt.show()

    if disk_diameter == 0:
        return 1

    cdr = cup_diameter / disk_diameter #cup_diameter / disk_diameter
    return cdr

# %%
def process_image(image_path, model):
    image = preprocess_image(image_path)
    cup, disc = segment(image, plot_seg = False, plot_hist = False )
    cdr_value = cdr(cup, disc, plot=False)
    return cdr_value

# %%
def unet_model(train_ds, test_ds):
    model = Sequential()

    # Encoder
    model.add(Conv2D(64, (3, 3), input_shape=(img_height, img_width, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Decoder
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(UpSampling2D(size=(2, 2)))

    # Output layer
    model.add(Conv2D(1, (1, 1), activation='sigmoid', padding='same'))
    checkpoint_path = 'datasets/real_combined_last_dataset/model_checkpoint.h5'

    if os.path.exists(checkpoint_path):
        print(f"Loading weights from checkpoint: {checkpoint_path}")
        try:
            model.load_weights(checkpoint_path)
            print("Weights loaded successfully.")
        except Exception as e:
            print(f"Error loading weights: {str(e)}")
    else:
        print(f"Checkpoint file not found at {checkpoint_path}")
    
    model_checkpoint = ModelCheckpoint(checkpoint_path, save_weights_only=True, save_best_only=False, save_freq='epoch')
    print("Training model")
    optimizer = Adam(learning_rate=1e-5)  # Use the updated optimizer
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])
    classifier = model.fit(train_ds, epochs=10, callbacks=[model_checkpoint])
    model_saver = model.save('datasets/real_combined_last_dataset/unet_model.h5')
    test_result = model.evaluate(test_ds)
    print(f"Test Loss: {test_result[0]}, Test Accuracy: {test_result[1]}")

    predictions = model.predict(test_ds)
    predictions_flat = predictions.reshape(predictions.shape[0], -1)
    column_names = [f"Pixel_{i}" for i in range(predictions_flat.shape[1])]
    df = pd.DataFrame(predictions_flat, columns=column_names)
    df.to_csv('datasets/real_combined_last_dataset/cup_and_disc_segmentation_results(copy of unet running again1).csv', index=False)

    # Save the entire model
    #model_saver = model.save('datasets/real_combined_last_dataset/unet_model.h5')
    return model

# %%
def process(base_dirs):
    all_data = []
    categories = ['glaucoma', 'normal', 'early_glaucoma']

    model = unet_model(train_ds,test_ds)

    #checkpoint_path = 'datasets/real_combined_last_dataset/model_checkpoint(copy of unet running again1).h5'
    #initial_epoch = get_last_epoch(model, checkpoint_path)

    # Train for 10 epochs initially
    #train_model(model, train_ds, test_ds)
    #train_model(model, train_ds, test_ds, initial_epoch=initial_epoch + 1, extra_epochs=1)

    for dataset_type, base_dir in base_dirs.items():
        for category in categories:
            category_dir = os.path.join(base_dir, category)
            for filename in os.listdir(category_dir):
                try:
                    if filename.endswith(".jpg") or filename.endswith(".png"):
                        image_path = os.path.join(category_dir, filename)

                        cdr_value = process_image(image_path, model)

                        if category == 'glaucoma':
                            label = 1
                        elif category == 'early_glaucoma':
                            label = -1
                        elif category == 'normal':
                            label = 0

                        all_data.append({
                            'filename': str(filename),
                            'label': label,
                            'cdr': cdr_value
                        })
                        print(f"{filename}, label: {label} - Pred_cdr: {cdr_value}")
                except Exception as e:
                    print(f"Error processing image: {image_path}")
                    print(f"Error message: {str(e)}")
                    break

    df = pd.DataFrame(all_data)
    output_directory = "/datasets/real_combined_last_dataset"
    os.makedirs(output_directory, exist_ok=True)
    output_file_path = os.path.join(output_directory, 'cupanddisc(cdr)(copy of unet running again1).csv')
    df.to_csv(output_file_path, index=False)

# %%
process = process(base_dirs)
# Out:
# Loading weights from checkpoint: datasets/real_combined_last_dataset/model_checkpoint.h5
# Weights loaded successfully.
# Training model
# Epoch 1/10
# 199/199 [==============================] - 2716s 14s/step - loss: 0.3230 - accuracy: 0.7074
# Epoch 2/10
# 199/199 [==============================] - 2123s 11s/step - loss: 0.3202 - accuracy: 0.7082
# Epoch 3/10
# 199/199 [==============================] - 2020s 10s/step - loss: 0.3180 - accuracy: 0.7088
# Epoch 4/10
# 199/199 [==============================] - 2160s 11s/step - loss: 0.3161 - accuracy: 0.7094
# Epoch 5/10
# 199/199 [==============================] - 2160s 11s/step - loss: 0.3143 - accuracy: 0.7098
# Epoch 6/10
# 199/199 [==============================] - 2265s 11s/step - loss: 0.3123 - accuracy: 0.7105
# Epoch 7/10
# 199/199 [==============================] - 2407s 12s/step - loss: 0.3110 - accuracy: 0.7110
# Epoch 8/10
# 199/199 [==============================] - 2500s 13s/step - loss: 0.3100 - accuracy: 0.7113
# Epoch 9/10
# 199/199 [==============================] - 3131s 16s/step - loss: 0.3083 - accuracy: 0.7115
# Epoch 10/10
# 199/199 [==============================] - 6427s 32s/step - loss: 0.3073 - accuracy: 0.7119
# E:\study material\miniproject-2\GalacticGrove\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 26/26 [==============================] - 68s 3s/step - loss: 0.3254 - accuracy: 0.6930
# Test Loss: 0.3254264295101166, Test Accuracy: 0.6929606795310974
# 26/26 [==============================] - 61s 2s/step
# 069.jpg, label: 1 - Pred_cdr: 0.1875
# 072.jpg, label: 1 - Pred_cdr: 0.045454545454545456
# 086.jpg, label: 1 - Pred_cdr: 0.058823529411764705
# 087.jpg, label: 1 - Pred_cdr: 0.10526315789473684
# 094.jpg, label: 1 - Pred_cdr: 1.0
# 097.jpg, label: 1 - Pred_cdr: 0.1875
# 1.png, label: 1 - Pred_cdr: 0.3076923076923077
# 10.png, label: 1 - Pred_cdr: 0.1111111111111111
# 100.png, label: 1 - Pred_cdr: 0.1875
# 101.png, label: 1 - Pred_cdr: 3.3333333333333335
# 102.png, label: 1 - Pred_cdr: 0.375
# 103.png, label: 1 - Pred_cdr: 0.2777777777777778
# 104.png, label: 1 - Pred_cdr: 0.42857142857142855
# 106.png, label: 1 - Pred_cdr: 0.6666666666666666
# 108.png, label: 1 - Pred_cdr: 0.1111111111111111
# 109.png, label: 1 - Pred_cdr: 0.21428571428571427
# 11.png, label: 1 - Pred_cdr: 0.06666666666666667
# 110.jpg, label: 1 - Pred_cdr: 0.6
# 110.png, label: 1 - Pred_cdr: 1.4285714285714286
# 111.png, label: 1 - Pred_cdr: 0.5
# 112.png, label: 1 - Pred_cdr: 0.23076923076923078
# 113.png, label: 1 - Pred_cdr: 0.19047619047619047
# 114.png, label: 1 - Pred_cdr: 0.05555555555555555
# 115.png, label: 1 - Pred_cdr: 0.5
# 116.jpg, label: 1 - Pred_cdr: 0.25
# 116.png, label: 1 - Pred_cdr: 0.6363636363636364
# 117.png, label: 1 - Pred_cdr: 0.3
# 118.png, label: 1 - Pred_cdr: 0.14285714285714285
# 119.png, label: 1 - Pred_cdr: 0.15384615384615385
# 12.png, label: 1 - Pred_cdr: 0.3
# 120.png, label: 1 - Pred_cdr: 0.5
# 121.png, label: 1 - Pred_cdr: 0.8421052631578947
# 122.png, label: 1 - Pred_cdr: 0.07692307692307693
# 123.png, label: 1 - Pred_cdr: 0.25
# 124.png, label: 1 - Pred_cdr: 0.5555555555555556
# 125.png, label: 1 - Pred_cdr: 0.2222222222222222
# 126.png, label: 1 - Pred_cdr: 1.0
# 127.png, label: 1 - Pred_cdr: 3.0
# 129.png, label: 1 - Pred_cdr: 0.75
# 13.png, label: 1 - Pred_cdr: 1.0
# 130.png, label: 1 - Pred_cdr: 0.2
# 131.png, label: 1 - Pred_cdr: 0.13333333333333333
# 133.png, label: 1 - Pred_cdr: 0.19047619047619047
# 134.png, label: 1 - Pred_cdr: 1.0
# 135.png, label: 1 - Pred_cdr: 0.17647058823529413
# 136.png, label: 1 - Pred_cdr: 0.1875
# 137.png, label: 1 - Pred_cdr: 0.14285714285714285
# 138.png, label: 1 - Pred_cdr: 1.0833333333333333
# 139.png, label: 1 - Pred_cdr: 11.0
# 14.png, label: 1 - Pred_cdr: 1.2
# 140.png, label: 1 - Pred_cdr: 0.8666666666666667
# 141.png, label: 1 - Pred_cdr: 1.1578947368421053
# 142.png, label: 1 - Pred_cdr: 1.25
# 143.png, label: 1 - Pred_cdr: 0.2857142857142857
# 144.png, label: 1 - Pred_cdr: 2.3333333333333335
# 145.png, label: 1 - Pred_cdr: 0.5
# 146.png, label: 1 - Pred_cdr: 0.2857142857142857
# 147.png, label: 1 - Pred_cdr: 0.10526315789473684
# 148.png, label: 1 - Pred_cdr: 0.14285714285714285
# 149.png, label: 1 - Pred_cdr: 0.46153846153846156
# 15.png, label: 1 - Pred_cdr: 1.0
# 150.png, label: 1 - Pred_cdr: 0.3125
# 151.png, label: 1 - Pred_cdr: 1.0
# 153.png, label: 1 - Pred_cdr: 0.4
# 155.png, label: 1 - Pred_cdr: 0.17391304347826086
# 156.png, label: 1 - Pred_cdr: 0.15789473684210525
# 157.png, label: 1 - Pred_cdr: 0.1111111111111111
# 158.png, label: 1 - Pred_cdr: 0.25
# 159.jpg, label: 1 - Pred_cdr: 0.2
# 159.png, label: 1 - Pred_cdr: 0.13333333333333333
# 16.png, label: 1 - Pred_cdr: 0.4
# 160.jpg, label: 1 - Pred_cdr: 1.0
# 160.png, label: 1 - Pred_cdr: 0.4
# 162.png, label: 1 - Pred_cdr: 2.5
# 163.png, label: 1 - Pred_cdr: 1.0625
# 164.png, label: 1 - Pred_cdr: 0.07142857142857142
# Error processing image: datasets/real_combined_last_dataset/train\glaucoma\165.jpg
# Error message: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'ellipse'
# > Overload resolution failed:
# >  - ellipse() missing required argument 'startAngle' (pos 5)
# >  - ellipse() missing required argument 'startAngle' (pos 5)
# >  - Can't parse 'box' as RotatedRect. Expected sequence length 3, got 4
# >  - Can't parse 'box' as RotatedRect. Expected sequence length 3, got 4
#
# Error processing image: datasets/real_combined_last_dataset/train\normal\003.jpg
# Error message: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'ellipse'
# > Overload resolution failed:
# >  - ellipse() missing required argument 'startAngle' (pos 5)
# >  - ellipse() missing required argument 'startAngle' (pos 5)
# >  - Can't parse 'box' as RotatedRect. Expected sequence length 3, got 4
# >  - Can't parse 'box' as RotatedRect. Expected sequence length 3, got 4
#
# 1.png, label: -1 - Pred_cdr: 0.3076923076923077
# 10.png, label: -1 - Pred_cdr: 0.1111111111111111
# 100.png, label: -1 - Pred_cdr: 0.1875
# 101.png, label: -1 - Pred_cdr: 3.3333333333333335
# 102.png, label: -1 - Pred_cdr: 0.375
# 103.png, label: -1 - Pred_cdr: 0.2777777777777778
# 104.png, label: -1 - Pred_cdr: 0.42857142857142855
# 105.png, label: -1 - Pred_cdr: 0.06666666666666667
# 106.png, label: -1 - Pred_cdr: 0.6666666666666666
# 107.png, label: -1 - Pred_cdr: 0.15384615384615385
# 108.png, label: -1 - Pred_cdr: 0.1111111111111111
# 109.png, label: -1 - Pred_cdr: 0.21428571428571427
# 11.png, label: -1 - Pred_cdr: 0.06666666666666667
# 110.png, label: -1 - Pred_cdr: 1.4285714285714286
# 111.png, label: -1 - Pred_cdr: 0.5
# 112.png, label: -1 - Pred_cdr: 0.23076923076923078
# 113.png, label: -1 - Pred_cdr: 0.19047619047619047
# 114.png, label: -1 - Pred_cdr: 0.05555555555555555
# 115.png, label: -1 - Pred_cdr: 0.5
# 116.png, label: -1 - Pred_cdr: 0.6363636363636364
# 117.png, label: -1 - Pred_cdr: 0.3
# 118.png, label: -1 - Pred_cdr: 0.14285714285714285
# 119.png, label: -1 - Pred_cdr: 0.15384615384615385
# 12.png, label: -1 - Pred_cdr: 0.3
# 120.png, label: -1 - Pred_cdr: 0.5
# 121.png, label: -1 - Pred_cdr: 0.8421052631578947
# 122.png, label: -1 - Pred_cdr: 0.07692307692307693
# 123.png, label: -1 - Pred_cdr: 0.25
# 124.png, label: -1 - Pred_cdr: 0.5555555555555556
# 125.png, label: -1 - Pred_cdr: 0.2222222222222222
# 126.png, label: -1 - Pred_cdr: 1.0
# 127.png, label: -1 - Pred_cdr: 3.0
# 128.png, label: -1 - Pred_cdr: 0.16666666666666666
# 129.png, label: -1 - Pred_cdr: 0.75
# 13.png, label: -1 - Pred_cdr: 1.0
# 130.png, label: -1 - Pred_cdr: 0.2
# 131.png, label: -1 - Pred_cdr: 0.13333333333333333
# 132.png, label: -1 - Pred_cdr: 0.3333333333333333
# 133.png, label: -1 - Pred_cdr: 0.19047619047619047
# 134.png, label: -1 - Pred_cdr: 1.0
# 135.png, label: -1 - Pred_cdr: 0.17647058823529413
# 136.png, label: -1 - Pred_cdr: 0.1875
# 137.png, label: -1 - Pred_cdr: 0.14285714285714285
# 138.png, label: -1 - Pred_cdr: 1.0833333333333333
# 139.png, label: -1 - Pred_cdr: 11.0
# 14.png, label: -1 - Pred_cdr: 1.2
# 140.png, label: -1 - Pred_cdr: 0.8666666666666667
# 141.png, label: -1 - Pred_cdr: 1.1578947368421053
# 142.png, label: -1 - Pred_cdr: 1.25
# 143.png, label: -1 - Pred_cdr: 0.2857142857142857
# 144.png, label: -1 - Pred_cdr: 2.3333333333333335
# 145.png, label: -1 - Pred_cdr: 0.5
# 146.png, label: -1 - Pred_cdr: 0.2857142857142857
# 147.png, label: -1 - Pred_cdr: 0.10526315789473684
# 148.png, label: -1 - Pred_cdr: 0.14285714285714285
# 149.png, label: -1 - Pred_cdr: 0.46153846153846156
# 15.png, label: -1 - Pred_cdr: 1.0
# 150.png, label: -1 - Pred_cdr: 0.3125
# 151.png, label: -1 - Pred_cdr: 1.0
# 152.png, label: -1 - Pred_cdr: 0.5
# 153.png, label: -1 - Pred_cdr: 0.4
# 154.png, label: -1 - Pred_cdr: 0.25
# 155.png, label: -1 - Pred_cdr: 0.17391304347826086
# 156.png, label: -1 - Pred_cdr: 0.15789473684210525
# 157.png, label: -1 - Pred_cdr: 0.1111111111111111
# 158.png, label: -1 - Pred_cdr: 0.25
# 159.png, label: -1 - Pred_cdr: 0.13333333333333333
# 16.png, label: -1 - Pred_cdr: 0.4
# 160.png, label: -1 - Pred_cdr: 0.4
# 161.png, label: -1 - Pred_cdr: 1.4
# 162.png, label: -1 - Pred_cdr: 2.5
# 163.png, label: -1 - Pred_cdr: 1.0625
# 164.png, label: -1 - Pred_cdr: 0.07142857142857142
# 165.png, label: -1 - Pred_cdr: 0.6666666666666666
# 166.png, label: -1 - Pred_cdr: 0.2857142857142857
# 167.png, label: -1 - Pred_cdr: 0.13333333333333333
# 168.png, label: -1 - Pred_cdr: 0.22727272727272727
# 169.png, label: -1 - Pred_cdr: 0.4
# 17.png, label: -1 - Pred_cdr: 0.07692307692307693
# 170.png, label: -1 - Pred_cdr: 1.0
# 171.png, label: -1 - Pred_cdr: 0.3333333333333333
# 172.png, label: -1 - Pred_cdr: 0.25
# 173.png, label: -1 - Pred_cdr: 4.0
# 174.png, label: -1 - Pred_cdr: 0.029411764705882353
# 175.png, label: -1 - Pred_cdr: 0.05263157894736842
# 176.png, label: -1 - Pred_cdr: 1.6666666666666667
# 177.png, label: -1 - Pred_cdr: 2.7857142857142856
# 178.png, label: -1 - Pred_cdr: 0.11764705882352941
# 179.png, label: -1 - Pred_cdr: 2.0
# 18.png, label: -1 - Pred_cdr: 3.0
# 180.png, label: -1 - Pred_cdr: 0.47058823529411764
# 181.png, label: -1 - Pred_cdr: 2.25
# 182.png, label: -1 - Pred_cdr: 0.1111111111111111
# 183.png, label: -1 - Pred_cdr: 1.0
# 184.png, label: -1 - Pred_cdr: 0.041666666666666664
# 185.png, label: -1 - Pred_cdr: 0.09523809523809523
# 186.png, label: -1 - Pred_cdr: 0.14285714285714285
# 187.png, label: -1 - Pred_cdr: 0.18181818181818182
# 188.png, label: -1 - Pred_cdr: 1.1428571428571428
# 189.png, label: -1 - Pred_cdr: 0.2
# 19.png, label: -1 - Pred_cdr: 2.0
# 190.png, label: -1 - Pred_cdr: 0.5
# 191.png, label: -1 - Pred_cdr: 0.1875
# 192.png, label: -1 - Pred_cdr: 0.16666666666666666
# 193.png, label: -1 - Pred_cdr: 0.1
# 194.png, label: -1 - Pred_cdr: 0.125
# 195.png, label: -1 - Pred_cdr: 0.45
# 196.png, label: -1 - Pred_cdr: 0.5
# 197.png, label: -1 - Pred_cdr: 0.05555555555555555
# 198.png, label: -1 - Pred_cdr: 1.5
# 199.png, label: -1 - Pred_cdr: 0.08695652173913043
# 2.png, label: -1 - Pred_cdr: 0.2857142857142857
# 20.png, label: -1 - Pred_cdr: 0.6666666666666666
# 200.png, label: -1 - Pred_cdr: 0.05555555555555555
# 201.png, label: -1 - Pred_cdr: 0.07692307692307693
# 202.png, label: -1 - Pred_cdr: 0.6666666666666666
# 203.png, label: -1 - Pred_cdr: 0.06666666666666667
# 204.png, label: -1 - Pred_cdr: 0.045454545454545456
# 205.png, label: -1 - Pred_cdr: 0.3157894736842105
# 206.png, label: -1 - Pred_cdr: 0.2857142857142857
# 207.png, label: -1 - Pred_cdr: 0.15
# 208.png, label: -1 - Pred_cdr: 0.14285714285714285
# 209.png, label: -1 - Pred_cdr: 0.2
# 21.png, label: -1 - Pred_cdr: 0.25
# 210.png, label: -1 - Pred_cdr: 13.0
# 211.png, label: -1 - Pred_cdr: 1.0
# 212.png, label: -1 - Pred_cdr: 0.36363636363636365
# 213.png, label: -1 - Pred_cdr: 7.0
# 214.png, label: -1 - Pred_cdr: 0.6923076923076923
# 215.png, label: -1 - Pred_cdr: 1.0
# 216.png, label: -1 - Pred_cdr: 0.037037037037037035
# 217.png, label: -1 - Pred_cdr: 0.3333333333333333
# 218.png, label: -1 - Pred_cdr: 0.1111111111111111
# 219.png, label: -1 - Pred_cdr: 0.21428571428571427
# 22.png, label: -1 - Pred_cdr: 0.7142857142857143
# 220.png, label: -1 - Pred_cdr: 1.2666666666666666
# 221.png, label: -1 - Pred_cdr: 0.3333333333333333
# 222.png, label: -1 - Pred_cdr: 0.125
# 223.png, label: -1 - Pred_cdr: 0.13636363636363635
# 224.png, label: -1 - Pred_cdr: 0.7272727272727273
# 225.png, label: -1 - Pred_cdr: 0.17647058823529413
# 226.png, label: -1 - Pred_cdr: 1.0
# 227.png, label: -1 - Pred_cdr: 1.3076923076923077
# 228.png, label: -1 - Pred_cdr: 1.125
# 229.png, label: -1 - Pred_cdr: 0.25
# 23.png, label: -1 - Pred_cdr: 1.0769230769230769
# 230.png, label: -1 - Pred_cdr: 1.1333333333333333
# 231.png, label: -1 - Pred_cdr: 0.0625
# 232.png, label: -1 - Pred_cdr: 0.25
# 233.png, label: -1 - Pred_cdr: 0.3333333333333333
# 234.png, label: -1 - Pred_cdr: 1.0588235294117647
# 235.png, label: -1 - Pred_cdr: 0.10526315789473684
# 236.png, label: -1 - Pred_cdr: 0.2631578947368421
# 237.png, label: -1 - Pred_cdr: 0.6666666666666666
# 238.png, label: -1 - Pred_cdr: 3.0
# 239.png, label: -1 - Pred_cdr: 0.07142857142857142
# 24.png, label: -1 - Pred_cdr: 0.2222222222222222
# 240.png, label: -1 - Pred_cdr: 0.14285714285714285
# 241.png, label: -1 - Pred_cdr: 0.6666666666666666
# 242.png, label: -1 - Pred_cdr: 0.07692307692307693
# 243.png, label: -1 - Pred_cdr: 0.125
# 244.png, label: -1 - Pred_cdr: 0.3076923076923077
# 245.png, label: -1 - Pred_cdr: 0.14285714285714285
# 246.png, label: -1 - Pred_cdr: 0.06666666666666667
# 247.png, label: -1 - Pred_cdr: 0.6666666666666666
# 248.png, label: -1 - Pred_cdr: 0.5
# 249.png, label: -1 - Pred_cdr: 0.375
# 25.png, label: -1 - Pred_cdr: 0.3333333333333333
# 250.png, label: -1 - Pred_cdr: 0.1
# 251.png, label: -1 - Pred_cdr: 1.0588235294117647
# 252.png, label: -1 - Pred_cdr: 0.3333333333333333
# 253.png, label: -1 - Pred_cdr: 0.05
# 254.png, label: -1 - Pred_cdr: 0.375
# 255.png, label: -1 - Pred_cdr: 2.0
# 256.png, label: -1 - Pred_cdr: 1.0
# 257.png, label: -1 - Pred_cdr: 0.05555555555555555
# 258.png, label: -1 - Pred_cdr: 0.125
# 259.png, label: -1 - Pred_cdr: 0.3333333333333333
# 26.png, label: -1 - Pred_cdr: 0.11764705882352941
# 260.png, label: -1 - Pred_cdr: 0.045454545454545456
# 261.png, label: -1 - Pred_cdr: 0.3684210526315789
# 262.png, label: -1 - Pred_cdr: 0.3076923076923077
# 263.png, label: -1 - Pred_cdr: 1.3333333333333333
# 264.png, label: -1 - Pred_cdr: 0.05
# 265.png, label: -1 - Pred_cdr: 0.06666666666666667
# 266.png, label: -1 - Pred_cdr: 0.3076923076923077
# 267.png, label: -1 - Pred_cdr: 0.1111111111111111
# 268.png, label: -1 - Pred_cdr: 0.15384615384615385
# 269.png, label: -1 - Pred_cdr: 1.5
# 27.png, label: -1 - Pred_cdr: 0.14285714285714285
# 270.png, label: -1 - Pred_cdr: 0.14285714285714285
# 271.png, label: -1 - Pred_cdr: 1.0
# 272.png, label: -1 - Pred_cdr: 0.42857142857142855
# 273.png, label: -1 - Pred_cdr: 0.14285714285714285
# 274.png, label: -1 - Pred_cdr: 1.5384615384615385
# 275.png, label: -1 - Pred_cdr: 2.0
# 276.png, label: -1 - Pred_cdr: 0.05263157894736842
# 277.png, label: -1 - Pred_cdr: 1.0
# 278.png, label: -1 - Pred_cdr: 0.6666666666666666
# 279.png, label: -1 - Pred_cdr: 0.14285714285714285
# 28.png, label: -1 - Pred_cdr: 0.125
# 280.png, label: -1 - Pred_cdr: 0.6666666666666666
# 281.png, label: -1 - Pred_cdr: 0.5
# 282.png, label: -1 - Pred_cdr: 2.0
# 283.png, label: -1 - Pred_cdr: 0.125
# 284.png, label: -1 - Pred_cdr: 0.0625
# 285.png, label: -1 - Pred_cdr: 0.4
# 286.png, label: -1 - Pred_cdr: 3.0
# 287.png, label: -1 - Pred_cdr: 0.05
# 288.png, label: -1 - Pred_cdr: 0.2
# 289.png, label: -1 - Pred_cdr: 0.25
# 29.png, label: -1 - Pred_cdr: 0.9333333333333333
# 3.png, label: -1 - Pred_cdr: 0.38461538461538464
# 30.png, label: -1 - Pred_cdr: 0.1
# 31.png, label: -1 - Pred_cdr: 0.2
# 32.png, label: -1 - Pred_cdr: 0.045454545454545456
# 33.png, label: -1 - Pred_cdr: 0.13636363636363635
# 34.png, label: -1 - Pred_cdr: 0.05
# 35.png, label: -1 - Pred_cdr: 1.5
# 36.png, label: -1 - Pred_cdr: 0.07692307692307693
# 37.png, label: -1 - Pred_cdr: 0.13333333333333333
# 38.png, label: -1 - Pred_cdr: 0.1111111111111111
# 39.png, label: -1 - Pred_cdr: 0.07692307692307693
# 4.png, label: -1 - Pred_cdr: 0.3333333333333333
# 40.png, label: -1 - Pred_cdr: 2.0
# 41.png, label: -1 - Pred_cdr: 1.4
# 42.png, label: -1 - Pred_cdr: 0.23529411764705882
# 43.png, label: -1 - Pred_cdr: 0.2
# 44.png, label: -1 - Pred_cdr: 0.16666666666666666
# 45.png, label: -1 - Pred_cdr: 0.1
# 46.png, label: -1 - Pred_cdr: 1.3333333333333333
# 47.png, label: -1 - Pred_cdr: 0.06666666666666667
# 48.png, label: -1 - Pred_cdr: 1.125
# 49.png, label: -1 - Pred_cdr: 0.07692307692307693
# 5.png, label: -1 - Pred_cdr: 0.13333333333333333
# 50.png, label: -1 - Pred_cdr: 1.0
# 51.png, label: -1 - Pred_cdr: 0.0625
# 52.png, label: -1 - Pred_cdr: 1.1538461538461537
# 53.png, label: -1 - Pred_cdr: 1.5
# 54.png, label: -1 - Pred_cdr: 0.23529411764705882
# 55.png, label: -1 - Pred_cdr: 0.17647058823529413
# 56.png, label: -1 - Pred_cdr: 0.21428571428571427
# 57.png, label: -1 - Pred_cdr: 0.5
# 58.png, label: -1 - Pred_cdr: 0.23529411764705882
# 59.png, label: -1 - Pred_cdr: 0.07142857142857142
# 6.png, label: -1 - Pred_cdr: 0.125
# 60.png, label: -1 - Pred_cdr: 0.2
# 61.png, label: -1 - Pred_cdr: 4.0
# 62.png, label: -1 - Pred_cdr: 0.5
# 63.png, label: -1 - Pred_cdr: 0.15384615384615385
# 64.png, label: -1 - Pred_cdr: 0.09090909090909091
# 65.png, label: -1 - Pred_cdr: 0.058823529411764705
# 66.png, label: -1 - Pred_cdr: 0.05555555555555555
# 67.png, label: -1 - Pred_cdr: 0.6666666666666666
# 68.png, label: -1 - Pred_cdr: 0.5
# 69.png, label: -1 - Pred_cdr: 1.6
# 7.png, label: -1 - Pred_cdr: 0.05555555555555555
# 70.png, label: -1 - Pred_cdr: 0.23076923076923078
# 71.png, label: -1 - Pred_cdr: 0.125
# 72.png, label: -1 - Pred_cdr: 0.14285714285714285
# 73.png, label: -1 - Pred_cdr: 0.15384615384615385
# 74.png, label: -1 - Pred_cdr: 1.0
# 75.png, label: -1 - Pred_cdr: 0.8461538461538461
# 76.png, label: -1 - Pred_cdr: 0.4
# 77.png, label: -1 - Pred_cdr: 0.5
# 78.png, label: -1 - Pred_cdr: 0.07692307692307693
# 79.png, label: -1 - Pred_cdr: 1.0476190476190477
# 8.png, label: -1 - Pred_cdr: 0.25
# 80.png, label: -1 - Pred_cdr: 0.1875
# 81.png, label: -1 - Pred_cdr: 0.13333333333333333
# 82.png, label: -1 - Pred_cdr: 0.2
# 83.png, label: -1 - Pred_cdr: 1.1428571428571428
# 84.png, label: -1 - Pred_cdr: 1.2666666666666666
# 85.png, label: -1 - Pred_cdr: 0.08333333333333333
# 86.png, label: -1 - Pred_cdr: 4.0
# 87.png, label: -1 - Pred_cdr: 0.0625
# 88.png, label: -1 - Pred_cdr: 1.0
# 89.png, label: -1 - Pred_cdr: 0.15384615384615385
# 9.png, label: -1 - Pred_cdr: 0.5
# 90.png, label: -1 - Pred_cdr: 0.5
# 91.png, label: -1 - Pred_cdr: 14.933333333333334
# 92.png, label: -1 - Pred_cdr: 0.6666666666666666
# 93.png, label: -1 - Pred_cdr: 0.06666666666666667
# 94.png, label: -1 - Pred_cdr: 1.0
# 95.png, label: -1 - Pred_cdr: 0.15384615384615385
# 96.png, label: -1 - Pred_cdr: 0.05
# 97.png, label: -1 - Pred_cdr: 0.058823529411764705
# 98.png, label: -1 - Pred_cdr: 0.35294117647058826
# 99.png, label: -1 - Pred_cdr: 0.11538461538461539
# 050.jpg, label: 1 - Pred_cdr: 0.043478260869565216
# 093.jpg, label: 1 - Pred_cdr: 0.05555555555555555
# 107.png, label: 1 - Pred_cdr: 0.15384615384615385
# 138.jpg, label: 1 - Pred_cdr: 0.5
# 152.png, label: 1 - Pred_cdr: 0.5
# 154.png, label: 1 - Pred_cdr: 0.25
# 161.png, label: 1 - Pred_cdr: 1.4
# 166.png, label: 1 - Pred_cdr: 0.2857142857142857
# 18.png, label: 1 - Pred_cdr: 3.0
# 181.png, label: 1 - Pred_cdr: 2.25
# 188.png, label: 1 - Pred_cdr: 1.1428571428571428
# 190.png, label: 1 - Pred_cdr: 0.5
# 200.png, label: 1 - Pred_cdr: 0.05555555555555555
# 203.png, label: 1 - Pred_cdr: 0.06666666666666667
# 213.png, label: 1 - Pred_cdr: 7.0
# 214.png, label: 1 - Pred_cdr: 0.6923076923076923
# 217.png, label: 1 - Pred_cdr: 0.3333333333333333
# 22.png, label: 1 - Pred_cdr: 0.7142857142857143
# 224.png, label: 1 - Pred_cdr: 0.7272727272727273
# 237.png, label: 1 - Pred_cdr: 0.6666666666666666
# 238.png, label: 1 - Pred_cdr: 3.0
# 240.jpg, label: 1 - Pred_cdr: 0.5
# 243.png, label: 1 - Pred_cdr: 0.125
# 247.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# 248.png, label: 1 - Pred_cdr: 0.5
# 255.png, label: 1 - Pred_cdr: 2.0
# 259.png, label: 1 - Pred_cdr: 0.3333333333333333
# 262.png, label: 1 - Pred_cdr: 0.3076923076923077
# 285.jpg, label: 1 - Pred_cdr: 0.35714285714285715
# 289.jpg, label: 1 - Pred_cdr: 0.0625
# 293.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# 294.jpg, label: 1 - Pred_cdr: 3.0
# 306.png, label: 1 - Pred_cdr: 0.07692307692307693
# 330.jpg, label: 1 - Pred_cdr: 0.25
# 345.jpg, label: 1 - Pred_cdr: 1.0
# 358.png, label: 1 - Pred_cdr: 0.14285714285714285
# 367.png, label: 1 - Pred_cdr: 1.0
# 385.png, label: 1 - Pred_cdr: 0.9285714285714286
# 392.png, label: 1 - Pred_cdr: 1.0
# 399.png, label: 1 - Pred_cdr: 0.4
# 419.png, label: 1 - Pred_cdr: 0.06666666666666667
# 427.png, label: 1 - Pred_cdr: 1.411764705882353
# 430.png, label: 1 - Pred_cdr: 1.0
# 440.png, label: 1 - Pred_cdr: 0.23076923076923078
# 441.jpg, label: 1 - Pred_cdr: 1.0
# 448.png, label: 1 - Pred_cdr: 0.0625
# 464.png, label: 1 - Pred_cdr: 0.5
# 49.png, label: 1 - Pred_cdr: 0.07692307692307693
# 53.png, label: 1 - Pred_cdr: 1.5
# 54.png, label: 1 - Pred_cdr: 0.23529411764705882
# 55.png, label: 1 - Pred_cdr: 0.17647058823529413
# 586.jpg, label: 1 - Pred_cdr: 0.11764705882352941
# 72.png, label: 1 - Pred_cdr: 0.14285714285714285
# 73.png, label: 1 - Pred_cdr: 0.15384615384615385
# 78.png, label: 1 - Pred_cdr: 0.07692307692307693
# 85.png, label: 1 - Pred_cdr: 0.08333333333333333
# 86.png, label: 1 - Pred_cdr: 4.0
# 90.png, label: 1 - Pred_cdr: 0.5
# drishtiGS_026.png, label: 1 - Pred_cdr: 1.1111111111111112
# drishtiGS_029.png, label: 1 - Pred_cdr: 1.0
# drishtiGS_045.png, label: 1 - Pred_cdr: 0.55
# drishtiGS_063.png, label: 1 - Pred_cdr: 22.0
# drishtiGS_071.png, label: 1 - Pred_cdr: 0.16666666666666666
# g.0012.jpg, label: 1 - Pred_cdr: 0.6666666666666666
# g.0030.jpg, label: 1 - Pred_cdr: 0.5
# g.0060.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.0069.jpg, label: 1 - Pred_cdr: 0.5
# g.0126.jpg, label: 1 - Pred_cdr: 1.0714285714285714
# g.0129.jpg, label: 1 - Pred_cdr: 0.0625
# g.0143.jpg, label: 1 - Pred_cdr: 1.0
# g.0198.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.0214.jpg, label: 1 - Pred_cdr: 0.10526315789473684
# g.0276.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# g.0384.jpg, label: 1 - Pred_cdr: 0.2
# g.0388.jpg, label: 1 - Pred_cdr: 0.5
# g.0421.jpg, label: 1 - Pred_cdr: 0.18181818181818182
# g.0465.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# g.0585.jpg, label: 1 - Pred_cdr: 0.8
# g.0589.jpg, label: 1 - Pred_cdr: 1.0833333333333333
# g.0635.jpg, label: 1 - Pred_cdr: 1.0
# g.0650.jpg, label: 1 - Pred_cdr: 1.0714285714285714
# g.0664.jpg, label: 1 - Pred_cdr: 0.35714285714285715
# g.0713.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# g.0719.jpg, label: 1 - Pred_cdr: 6.5
# g.0724.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# g.0820.jpg, label: 1 - Pred_cdr: 1.0
# g.0825.jpg, label: 1 - Pred_cdr: 1.2307692307692308
# g.0833.jpg, label: 1 - Pred_cdr: 1.0909090909090908
# g.0888.jpg, label: 1 - Pred_cdr: 6.0
# g.0909.jpg, label: 1 - Pred_cdr: 1.0
# g.0913.jpg, label: 1 - Pred_cdr: 1.0714285714285714
# g.0916.jpg, label: 1 - Pred_cdr: 0.46153846153846156
# g.1057.jpg, label: 1 - Pred_cdr: 0.35714285714285715
# g.1138.jpg, label: 1 - Pred_cdr: 1.0
# g.1148.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# g.1157.jpg, label: 1 - Pred_cdr: 0.5
# g.1182.jpg, label: 1 - Pred_cdr: 0.35294117647058826
# g.1247.jpg, label: 1 - Pred_cdr: 0.0625
# g.1280.jpg, label: 1 - Pred_cdr: 1.7
# g.1380.jpg, label: 1 - Pred_cdr: 2.0
# g.1405.jpg, label: 1 - Pred_cdr: 0.125
# g.1490.jpg, label: 1 - Pred_cdr: 0.2222222222222222
# g.1536.jpg, label: 1 - Pred_cdr: 1.0
# g.1552.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# g.1680.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.1728.jpg, label: 1 - Pred_cdr: 0.36363636363636365
# g.1735.jpg, label: 1 - Pred_cdr: 1.5714285714285714
# g.1826.jpg, label: 1 - Pred_cdr: 0.26666666666666666
# g.1849.jpg, label: 1 - Pred_cdr: 1.0
# g.1866.jpg, label: 1 - Pred_cdr: 0.125
# g.1897.jpg, label: 1 - Pred_cdr: 0.4
# g.1906.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# g.1926.jpg, label: 1 - Pred_cdr: 2.0
# g.1977.jpg, label: 1 - Pred_cdr: 0.46153846153846156
# g.2009.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# g.2020.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# g.2070.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# g.2072.jpg, label: 1 - Pred_cdr: 0.0625
# g.2117.jpg, label: 1 - Pred_cdr: 0.2
# g.2128.jpg, label: 1 - Pred_cdr: 0.2857142857142857
# g.2154.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# g.2227.jpg, label: 1 - Pred_cdr: 0.047619047619047616
# g.2228.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# g.2310.jpg, label: 1 - Pred_cdr: 3.5
# g.2316.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# g.2341.jpg, label: 1 - Pred_cdr: 1.25
# g.2362.jpg, label: 1 - Pred_cdr: 0.2
# g.2377.jpg, label: 1 - Pred_cdr: 0.2857142857142857
# g.2438.jpg, label: 1 - Pred_cdr: 0.8461538461538461
# g.2445.jpg, label: 1 - Pred_cdr: 0.18181818181818182
# g.2473.jpg, label: 1 - Pred_cdr: 1.0
# g.2506.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# g.2508.jpg, label: 1 - Pred_cdr: 1.0
# g.2509.jpg, label: 1 - Pred_cdr: 0.35714285714285715
# g.2523.jpg, label: 1 - Pred_cdr: 0.8181818181818182
# g.2525.jpg, label: 1 - Pred_cdr: 0.1
# g.2684.jpg, label: 1 - Pred_cdr: 10.0
# g.2736.jpg, label: 1 - Pred_cdr: 0.4
# g.2851.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# g.2947.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# g.2953.jpg, label: 1 - Pred_cdr: 1.1538461538461537
# g.2959.jpg, label: 1 - Pred_cdr: 0.45454545454545453
# g.2961.jpg, label: 1 - Pred_cdr: 0.1875
# g.2981.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.2990.jpg, label: 1 - Pred_cdr: 1.0
# g.3034.jpg, label: 1 - Pred_cdr: 3.0
# g.3113.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# g.3114.jpg, label: 1 - Pred_cdr: 0.5
# g.3150.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# g.3168.jpg, label: 1 - Pred_cdr: 0.125
# g.3236.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# g.3244.jpg, label: 1 - Pred_cdr: 1.0
# g.3254.jpg, label: 1 - Pred_cdr: 0.11764705882352941
# g.3263.jpg, label: 1 - Pred_cdr: 0.2
# g.3265.jpg, label: 1 - Pred_cdr: 0.0625
# g.3271.jpg, label: 1 - Pred_cdr: 0.9230769230769231
# g.3365.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.3377.jpg, label: 1 - Pred_cdr: 1.0
# g.3383.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# g.3385.jpg, label: 1 - Pred_cdr: 4.0
# g.3411.jpg, label: 1 - Pred_cdr: 1.0
# g.3471.jpg, label: 1 - Pred_cdr: 0.21428571428571427
# g.3478.jpg, label: 1 - Pred_cdr: 0.5
# g.3535.jpg, label: 1 - Pred_cdr: 2.0
# g.3622.jpg, label: 1 - Pred_cdr: 15.0
# g.3635.jpg, label: 1 - Pred_cdr: 1.0833333333333333
# g.3640.jpg, label: 1 - Pred_cdr: 0.4166666666666667
# g.3642.jpg, label: 1 - Pred_cdr: 1.0
# g.3662.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# g.3686.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# g.3701.jpg, label: 1 - Pred_cdr: 0.25
# g.3710.jpg, label: 1 - Pred_cdr: 1.0666666666666667
# g.3712.jpg, label: 1 - Pred_cdr: 0.23529411764705882
# g.3748.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# g.3839.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# g.3854.jpg, label: 1 - Pred_cdr: 2.75
# g.3863.jpg, label: 1 - Pred_cdr: 0.058823529411764705
# g.3887.jpg, label: 1 - Pred_cdr: 1.0
# g.3937.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# g.3946.jpg, label: 1 - Pred_cdr: 1.0
# g.3961.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# g.3974.jpg, label: 1 - Pred_cdr: 0.1
# g.4029.jpg, label: 1 - Pred_cdr: 3.0
# g.4084.jpg, label: 1 - Pred_cdr: 0.125
# g.4108.jpg, label: 1 - Pred_cdr: 1.0625
# g.4122.jpg, label: 1 - Pred_cdr: 12.0
# g.4126.jpg, label: 1 - Pred_cdr: 0.3076923076923077
# g.4129.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.4144.jpg, label: 1 - Pred_cdr: 0.2
# g.4199.jpg, label: 1 - Pred_cdr: 0.2222222222222222
# g.4292.jpg, label: 1 - Pred_cdr: 1.0666666666666667
# g.4321.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# g.4367.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# g.4408.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# g.4449.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# g.4549.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.4577.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# g.4599.jpg, label: 1 - Pred_cdr: 0.9333333333333333
# g.4621.jpg, label: 1 - Pred_cdr: 1.0
# g.4656.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.4681.jpg, label: 1 - Pred_cdr: 0.05555555555555555
# g.4732.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# g.4785.jpg, label: 1 - Pred_cdr: 0.21428571428571427
# g.4796.jpg, label: 1 - Pred_cdr: 2.0
# g.4808.jpg, label: 1 - Pred_cdr: 0.5
# g.4816.jpg, label: 1 - Pred_cdr: 1.1875
# g.4915.jpg, label: 1 - Pred_cdr: 1.0
# g.4935.jpg, label: 1 - Pred_cdr: 1.0
# g.4999.jpg, label: 1 - Pred_cdr: 0.05
# g.5051.jpg, label: 1 - Pred_cdr: 1.0
# g.5059.jpg, label: 1 - Pred_cdr: 0.05263157894736842
# g.5067.jpg, label: 1 - Pred_cdr: 3.0
# g.5105.jpg, label: 1 - Pred_cdr: 1.0
# g.5166.jpg, label: 1 - Pred_cdr: 1.0
# g.5237.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.5244.jpg, label: 1 - Pred_cdr: 15.0
# g.5259.jpg, label: 1 - Pred_cdr: 1.8
# g.5268.jpg, label: 1 - Pred_cdr: 0.6666666666666666
# g.5301.jpg, label: 1 - Pred_cdr: 1.4
# g.5310.jpg, label: 1 - Pred_cdr: 0.5
# g.5341.jpg, label: 1 - Pred_cdr: 0.75
# g.5405.jpg, label: 1 - Pred_cdr: 0.1875
# g.5406.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# g.5498.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.5542.jpg, label: 1 - Pred_cdr: 0.4
# g.5546.jpg, label: 1 - Pred_cdr: 1.0
# g.5580.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# g.5657.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# g.5664.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# g.5672.jpg, label: 1 - Pred_cdr: 1.0
# g.5696.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# g.5701.jpg, label: 1 - Pred_cdr: 0.7333333333333333
# g.5747.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# g.5748.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# g.5750.jpg, label: 1 - Pred_cdr: 1.0625
# g.5772.jpg, label: 1 - Pred_cdr: 0.1
# g.5788.jpg, label: 1 - Pred_cdr: 1.3333333333333333
# ng.0001.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.0006.jpg, label: 1 - Pred_cdr: 1.0
# ng.0022.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.0064.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.0124.jpg, label: 1 - Pred_cdr: 1.0
# ng.0142.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.0234.jpg, label: 1 - Pred_cdr: 0.3076923076923077
# ng.0264.jpg, label: 1 - Pred_cdr: 0.21428571428571427
# ng.0272.jpg, label: 1 - Pred_cdr: 1.0
# ng.0278.jpg, label: 1 - Pred_cdr: 1.5
# ng.0307.jpg, label: 1 - Pred_cdr: 1.6666666666666667
# ng.0315.jpg, label: 1 - Pred_cdr: 7.0
# ng.0319.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# ng.0320.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.0337.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.0339.jpg, label: 1 - Pred_cdr: 0.5
# ng.0340.jpg, label: 1 - Pred_cdr: 1.0
# ng.0341.jpg, label: 1 - Pred_cdr: 1.5714285714285714
# ng.0345.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# ng.0364.jpg, label: 1 - Pred_cdr: 1.5
# ng.0397.jpg, label: 1 - Pred_cdr: 1.3
# ng.0407.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.0416.jpg, label: 1 - Pred_cdr: 0.2857142857142857
# ng.0417.jpg, label: 1 - Pred_cdr: 0.1
# ng.0422.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.0472.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# ng.0474.jpg, label: 1 - Pred_cdr: 0.5
# ng.0511.jpg, label: 1 - Pred_cdr: 0.5
# ng.0522.jpg, label: 1 - Pred_cdr: 0.5
# ng.0543.jpg, label: 1 - Pred_cdr: 1.0
# ng.0550.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.0570.jpg, label: 1 - Pred_cdr: 0.5
# ng.0579.jpg, label: 1 - Pred_cdr: 0.5
# ng.0626.jpg, label: 1 - Pred_cdr: 7.5
# ng.0639.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.0643.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.0654.jpg, label: 1 - Pred_cdr: 0.5
# ng.0697.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.0712.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.0720.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# ng.0741.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.0767.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.0771.jpg, label: 1 - Pred_cdr: 1.1538461538461537
# ng.0776.jpg, label: 1 - Pred_cdr: 1.0
# ng.0795.jpg, label: 1 - Pred_cdr: 2.0
# ng.0808.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.0840.jpg, label: 1 - Pred_cdr: 1.0
# ng.0846.jpg, label: 1 - Pred_cdr: 0.7142857142857143
# ng.0856.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.0867.jpg, label: 1 - Pred_cdr: 2.1666666666666665
# ng.0884.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.0892.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.0908.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.0924.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.0929.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.0956.jpg, label: 1 - Pred_cdr: 1.0
# ng.0958.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.1085.jpg, label: 1 - Pred_cdr: 0.2727272727272727
# ng.1089.jpg, label: 1 - Pred_cdr: 0.1
# ng.1090.jpg, label: 1 - Pred_cdr: 1.0
# ng.1137.jpg, label: 1 - Pred_cdr: 0.7142857142857143
# ng.1144.jpg, label: 1 - Pred_cdr: 0.0625
# ng.1167.jpg, label: 1 - Pred_cdr: 1.0
# ng.1179.jpg, label: 1 - Pred_cdr: 0.6666666666666666
# ng.1183.jpg, label: 1 - Pred_cdr: 0.25
# ng.1197.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.1228.jpg, label: 1 - Pred_cdr: 1.0
# ng.1245.jpg, label: 1 - Pred_cdr: 1.2142857142857142
# ng.1250.jpg, label: 1 - Pred_cdr: 1.0
# ng.1251.jpg, label: 1 - Pred_cdr: 0.375
# ng.1329.jpg, label: 1 - Pred_cdr: 0.4666666666666667
# ng.1365.jpg, label: 1 - Pred_cdr: 1.0
# ng.1378.jpg, label: 1 - Pred_cdr: 1.0
# ng.1387.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.1390.jpg, label: 1 - Pred_cdr: 0.5625
# ng.1422.jpg, label: 1 - Pred_cdr: 0.4
# ng.1423.jpg, label: 1 - Pred_cdr: 3.0
# ng.1462.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.1467.jpg, label: 1 - Pred_cdr: 0.2
# ng.1471.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.1479.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.1557.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# ng.1562.jpg, label: 1 - Pred_cdr: 0.8571428571428571
# ng.1565.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.1574.jpg, label: 1 - Pred_cdr: 2.6
# ng.1575.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.1580.jpg, label: 1 - Pred_cdr: 0.7142857142857143
# ng.1623.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.1640.jpg, label: 1 - Pred_cdr: 0.125
# ng.1708.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.1712.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.1763.jpg, label: 1 - Pred_cdr: 0.38461538461538464
# ng.1772.jpg, label: 1 - Pred_cdr: 0.2857142857142857
# ng.1776.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.1779.jpg, label: 1 - Pred_cdr: 6.0
# ng.1785.jpg, label: 1 - Pred_cdr: 1.0
# ng.1830.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.1835.jpg, label: 1 - Pred_cdr: 1.3846153846153846
# ng.1884.jpg, label: 1 - Pred_cdr: 1.0
# ng.1931.jpg, label: 1 - Pred_cdr: 2.0
# ng.1955.jpg, label: 1 - Pred_cdr: 0.1875
# ng.1961.jpg, label: 1 - Pred_cdr: 0.2
# ng.1992.jpg, label: 1 - Pred_cdr: 2.5
# ng.2046.jpg, label: 1 - Pred_cdr: 0.3125
# ng.2080.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.2086.jpg, label: 1 - Pred_cdr: 1.2307692307692308
# ng.2089.jpg, label: 1 - Pred_cdr: 1.0
# ng.2143.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# ng.2144.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.2160.jpg, label: 1 - Pred_cdr: 0.125
# ng.2178.jpg, label: 1 - Pred_cdr: 0.38461538461538464
# ng.2196.jpg, label: 1 - Pred_cdr: 1.1666666666666667
# ng.2206.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.2244.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.2248.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.2260.jpg, label: 1 - Pred_cdr: 2.5
# ng.2263.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.2269.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.2279.jpg, label: 1 - Pred_cdr: 5.0
# ng.2304.jpg, label: 1 - Pred_cdr: 0.125
# ng.2323.jpg, label: 1 - Pred_cdr: 0.2777777777777778
# ng.2391.jpg, label: 1 - Pred_cdr: 1.0
# ng.2392.jpg, label: 1 - Pred_cdr: 3.75
# ng.2393.jpg, label: 1 - Pred_cdr: 0.058823529411764705
# ng.2421.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.2457.jpg, label: 1 - Pred_cdr: 1.0
# ng.2488.jpg, label: 1 - Pred_cdr: 0.5
# ng.2496.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.2510.jpg, label: 1 - Pred_cdr: 1.6
# ng.2512.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.2522.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.2541.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.2546.jpg, label: 1 - Pred_cdr: 1.0
# ng.2558.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.2587.jpg, label: 1 - Pred_cdr: 0.4444444444444444
# ng.2625.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# ng.2629.jpg, label: 1 - Pred_cdr: 4.5
# ng.2631.jpg, label: 1 - Pred_cdr: 1.0
# ng.2645.jpg, label: 1 - Pred_cdr: 0.2
# ng.2647.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.2654.jpg, label: 1 - Pred_cdr: 0.9230769230769231
# ng.2696.jpg, label: 1 - Pred_cdr: 0.625
# ng.2699.jpg, label: 1 - Pred_cdr: 12.0
# ng.2710.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.2717.jpg, label: 1 - Pred_cdr: 1.0
# ng.2724.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.2727.jpg, label: 1 - Pred_cdr: 1.0
# ng.2728.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.2776.jpg, label: 1 - Pred_cdr: 0.5
# ng.2800.jpg, label: 1 - Pred_cdr: 2.0
# ng.2893.jpg, label: 1 - Pred_cdr: 0.8
# ng.2945.jpg, label: 1 - Pred_cdr: 0.7
# ng.2982.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.2992.jpg, label: 1 - Pred_cdr: 1.5
# ng.3001.jpg, label: 1 - Pred_cdr: 1.0
# ng.3026.jpg, label: 1 - Pred_cdr: 0.38095238095238093
# ng.3031.jpg, label: 1 - Pred_cdr: 0.9166666666666666
# ng.3036.jpg, label: 1 - Pred_cdr: 0.2
# ng.3054.jpg, label: 1 - Pred_cdr: 1.1818181818181819
# ng.3082.jpg, label: 1 - Pred_cdr: 0.15789473684210525
# ng.3122.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.3137.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# ng.3151.jpg, label: 1 - Pred_cdr: 0.2
# ng.3172.jpg, label: 1 - Pred_cdr: 0.05
# ng.3184.jpg, label: 1 - Pred_cdr: 0.9285714285714286
# ng.3202.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.3208.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# ng.3212.jpg, label: 1 - Pred_cdr: 1.3333333333333333
# ng.3225.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.3226.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.3230.jpg, label: 1 - Pred_cdr: 1.6666666666666667
# ng.3240.jpg, label: 1 - Pred_cdr: 7.5
# ng.3267.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.3273.jpg, label: 1 - Pred_cdr: 1.0
# ng.3279.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.3314.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# ng.3316.jpg, label: 1 - Pred_cdr: 0.05555555555555555
# ng.3349.jpg, label: 1 - Pred_cdr: 0.2
# ng.3366.jpg, label: 1 - Pred_cdr: 1.0
# ng.3388.jpg, label: 1 - Pred_cdr: 1.0
# ng.3389.jpg, label: 1 - Pred_cdr: 0.25
# ng.3423.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.3454.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.3460.jpg, label: 1 - Pred_cdr: 1.0666666666666667
# ng.3485.jpg, label: 1 - Pred_cdr: 0.5
# ng.3489.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.3550.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.3557.jpg, label: 1 - Pred_cdr: 0.7619047619047619
# ng.3593.jpg, label: 1 - Pred_cdr: 14.0
# ng.3614.jpg, label: 1 - Pred_cdr: 0.9230769230769231
# ng.3616.jpg, label: 1 - Pred_cdr: 1.0
# ng.3632.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.3657.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.3663.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.3680.jpg, label: 1 - Pred_cdr: 4.0
# ng.3716.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.3773.jpg, label: 1 - Pred_cdr: 3.25
# ng.3779.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# ng.3780.jpg, label: 1 - Pred_cdr: 0.6666666666666666
# ng.3785.jpg, label: 1 - Pred_cdr: 1.0
# ng.3788.jpg, label: 1 - Pred_cdr: 0.25
# ng.3793.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.3822.jpg, label: 1 - Pred_cdr: 1.0714285714285714
# ng.3828.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.3830.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.3865.jpg, label: 1 - Pred_cdr: 1.0
# ng.3885.jpg, label: 1 - Pred_cdr: 0.5
# ng.3904.jpg, label: 1 - Pred_cdr: 0.21428571428571427
# ng.3973.jpg, label: 1 - Pred_cdr: 0.3125
# ng.4004.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.4052.jpg, label: 1 - Pred_cdr: 0.25
# ng.4068.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4138.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.4151.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4157.jpg, label: 1 - Pred_cdr: 0.5
# ng.4176.jpg, label: 1 - Pred_cdr: 0.7142857142857143
# ng.4188.jpg, label: 1 - Pred_cdr: 1.6666666666666667
# ng.4205.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.4220.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4230.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.4236.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4237.jpg, label: 1 - Pred_cdr: 0.5
# ng.4242.jpg, label: 1 - Pred_cdr: 1.3076923076923077
# ng.4260.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4308.jpg, label: 1 - Pred_cdr: 1.0
# ng.4311.jpg, label: 1 - Pred_cdr: 0.4166666666666667
# ng.4328.jpg, label: 1 - Pred_cdr: 0.18181818181818182
# ng.4344.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# ng.4357.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.4381.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.4416.jpg, label: 1 - Pred_cdr: 0.8125
# ng.4417.jpg, label: 1 - Pred_cdr: 4.333333333333333
# ng.4424.jpg, label: 1 - Pred_cdr: 1.3636363636363635
# ng.4430.jpg, label: 1 - Pred_cdr: 0.5
# ng.4432.jpg, label: 1 - Pred_cdr: 0.9333333333333333
# ng.4462.jpg, label: 1 - Pred_cdr: 0.1111111111111111
# ng.4466.jpg, label: 1 - Pred_cdr: 0.1
# ng.4481.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.4482.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.4503.jpg, label: 1 - Pred_cdr: 0.5
# ng.4508.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.4514.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# ng.4539.jpg, label: 1 - Pred_cdr: 6.0
# ng.4554.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.4561.jpg, label: 1 - Pred_cdr: 6.5
# ng.4568.jpg, label: 1 - Pred_cdr: 1.75
# ng.4586.jpg, label: 1 - Pred_cdr: 3.25
# ng.4670.jpg, label: 1 - Pred_cdr: 0.0625
# ng.4713.jpg, label: 1 - Pred_cdr: 1.0
# ng.4716.jpg, label: 1 - Pred_cdr: 0.3076923076923077
# ng.4721.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# ng.4722.jpg, label: 1 - Pred_cdr: 0.2222222222222222
# ng.4746.jpg, label: 1 - Pred_cdr: 1.7777777777777777
# ng.4751.jpg, label: 1 - Pred_cdr: 1.5
# ng.4768.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.4811.jpg, label: 1 - Pred_cdr: 1.5
# ng.4813.jpg, label: 1 - Pred_cdr: 5.333333333333333
# ng.4822.jpg, label: 1 - Pred_cdr: 0.5
# ng.4831.jpg, label: 1 - Pred_cdr: 0.9333333333333333
# ng.4843.jpg, label: 1 - Pred_cdr: 1.0
# ng.4848.jpg, label: 1 - Pred_cdr: 1.0769230769230769
# ng.4868.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.4890.jpg, label: 1 - Pred_cdr: 1.5
# ng.4898.jpg, label: 1 - Pred_cdr: 1.0
# ng.4901.jpg, label: 1 - Pred_cdr: 1.0
# ng.4921.jpg, label: 1 - Pred_cdr: 0.2857142857142857
# ng.4934.jpg, label: 1 - Pred_cdr: 0.5
# ng.4956.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.4969.jpg, label: 1 - Pred_cdr: 2.0
# ng.4981.jpg, label: 1 - Pred_cdr: 0.75
# ng.4982.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.5006.jpg, label: 1 - Pred_cdr: 1.5
# ng.5022.jpg, label: 1 - Pred_cdr: 1.4444444444444444
# ng.5036.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.5039.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.5049.jpg, label: 1 - Pred_cdr: 0.5
# ng.5063.jpg, label: 1 - Pred_cdr: 0.08333333333333333
# ng.5078.jpg, label: 1 - Pred_cdr: 0.3
# ng.5094.jpg, label: 1 - Pred_cdr: 1.3333333333333333
# ng.5098.jpg, label: 1 - Pred_cdr: 1.0
# ng.5102.jpg, label: 1 - Pred_cdr: 0.2
# ng.5116.jpg, label: 1 - Pred_cdr: 1.1538461538461537
# ng.5117.jpg, label: 1 - Pred_cdr: 1.1428571428571428
# ng.5134.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.5149.jpg, label: 1 - Pred_cdr: 0.06666666666666667
# ng.5185.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.5201.jpg, label: 1 - Pred_cdr: 0.2222222222222222
# ng.5236.jpg, label: 1 - Pred_cdr: 0.15384615384615385
# ng.5252.jpg, label: 1 - Pred_cdr: 1.0
# ng.5289.jpg, label: 1 - Pred_cdr: 0.25
# ng.5322.jpg, label: 1 - Pred_cdr: 1.0833333333333333
# ng.5353.jpg, label: 1 - Pred_cdr: 0.25
# ng.5361.jpg, label: 1 - Pred_cdr: 1.0
# ng.5372.jpg, label: 1 - Pred_cdr: 0.5
# ng.5378.jpg, label: 1 - Pred_cdr: 1.0
# ng.5387.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.5388.jpg, label: 1 - Pred_cdr: 0.07142857142857142
# ng.5391.jpg, label: 1 - Pred_cdr: 0.07692307692307693
# ng.5462.jpg, label: 1 - Pred_cdr: 1.5
# ng.5487.jpg, label: 1 - Pred_cdr: 4.0
# ng.5495.jpg, label: 1 - Pred_cdr: 0.75
# ng.5558.jpg, label: 1 - Pred_cdr: 1.0
# ng.5567.jpg, label: 1 - Pred_cdr: 0.6875
# ng.5571.jpg, label: 1 - Pred_cdr: 0.09090909090909091
# ng.5620.jpg, label: 1 - Pred_cdr: 0.14285714285714285
# ng.5674.jpg, label: 1 - Pred_cdr: 1.0
# ng.5675.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.5681.jpg, label: 1 - Pred_cdr: 0.13333333333333333
# ng.5716.jpg, label: 1 - Pred_cdr: 0.23076923076923078
# ng.5799.jpg, label: 1 - Pred_cdr: 1.0
# ng.5828.jpg, label: 1 - Pred_cdr: 1.0
# ng.5836.jpg, label: 1 - Pred_cdr: 0.3333333333333333
# ng.5839.jpg, label: 1 - Pred_cdr: 0.16666666666666666
# ng.5845.jpg, label: 1 - Pred_cdr: 1.1666666666666667
# 002.jpg, label: 0 - Pred_cdr: 0.3333333333333333
# 019.jpg, label: 0 - Pred_cdr: 0.08333333333333333
# 053.jpg, label: 0 - Pred_cdr: 1.0
# 060.jpg, label: 0 - Pred_cdr: 0.16666666666666666
# 067.jpg, label: 0 - Pred_cdr: 0.1111111111111111
# 070.jpg, label: 0 - Pred_cdr: 0.058823529411764705
# 082.jpg, label: 0 - Pred_cdr: 0.06666666666666667
# 085.jpg, label: 0 - Pred_cdr: 0.3333333333333333
# 107.png, label: 0 - Pred_cdr: 1.0
# 120.png, label: 0 - Pred_cdr: 0.058823529411764705
# 131.png, label: 0 - Pred_cdr: 0.16666666666666666
# 133.png, label: 0 - Pred_cdr: 0.1
# 138.png, label: 0 - Pred_cdr: 0.07692307692307693
# 143.jpg, label: 0 - Pred_cdr: 0.5
# 147.png, label: 0 - Pred_cdr: 0.4166666666666667
# 151.jpg, label: 0 - Pred_cdr: 1.0
# 152.jpg, label: 0 - Pred_cdr: 2.0
# 174.jpg, label: 0 - Pred_cdr: 0.08333333333333333
# 183.png, label: 0 - Pred_cdr: 0.2857142857142857
# 186.png, label: 0 - Pred_cdr: 1.0
# 190.jpg, label: 0 - Pred_cdr: 0.14285714285714285
# 192.jpg, label: 0 - Pred_cdr: 0.07692307692307693
# 194.png, label: 0 - Pred_cdr: 0.125
# 2.png, label: 0 - Pred_cdr: 1.0
# 203.jpg, label: 0 - Pred_cdr: 0.07692307692307693
# 205.png, label: 0 - Pred_cdr: 0.4
# 217.jpg, label: 0 - Pred_cdr: 0.125
# 22.png, label: 0 - Pred_cdr: 0.06666666666666667
# 221.png, label: 0 - Pred_cdr: 0.5
# 232.png, label: 0 - Pred_cdr: 0.10526315789473684
# 236.jpg, label: 0 - Pred_cdr: 0.16666666666666666
# 240.png, label: 0 - Pred_cdr: 0.07142857142857142
# 249.jpg, label: 0 - Pred_cdr: 0.2
# 251.jpg, label: 0 - Pred_cdr: 0.1
# 257.jpg, label: 0 - Pred_cdr: 1.0
# 267.png, label: 0 - Pred_cdr: 0.75
# 272.png, label: 0 - Pred_cdr: 0.6666666666666666
# 274.png, label: 0 - Pred_cdr: 0.05555555555555555
# 291.jpg, label: 0 - Pred_cdr: 1.0
# 295.jpg, label: 0 - Pred_cdr: 0.058823529411764705
# 306.png, label: 0 - Pred_cdr: 0.18181818181818182
# 308.png, label: 0 - Pred_cdr: 0.16666666666666666
# 310.png, label: 0 - Pred_cdr: 0.07692307692307693
# 314.png, label: 0 - Pred_cdr: 0.2222222222222222
# 315.png, label: 0 - Pred_cdr: 0.15384615384615385
# 317.png, label: 0 - Pred_cdr: 0.05263157894736842
# 318.jpg, label: 0 - Pred_cdr: 0.07692307692307693
# 323.jpg, label: 0 - Pred_cdr: 2.0
# 326.png, label: 0 - Pred_cdr: 0.1
# 333.jpg, label: 0 - Pred_cdr: 0.5
# 337.png, label: 0 - Pred_cdr: 0.09090909090909091
# 339.jpg, label: 0 - Pred_cdr: 0.5
# 36.png, label: 0 - Pred_cdr: 5.0
# 360.jpg, label: 0 - Pred_cdr: 0.5
# 374.jpg, label: 0 - Pred_cdr: 2.0
# 376.jpg, label: 0 - Pred_cdr: 1.0
# 389.png, label: 0 - Pred_cdr: 0.4
# 393.jpg, label: 0 - Pred_cdr: 0.125
# 394.png, label: 0 - Pred_cdr: 0.25
# 402.png, label: 0 - Pred_cdr: 0.13333333333333333
# 406.jpg, label: 0 - Pred_cdr: 0.1875
# 406.png, label: 0 - Pred_cdr: 0.125
# 411.jpg, label: 0 - Pred_cdr: 0.375
# 414.jpg, label: 0 - Pred_cdr: 0.8333333333333334
# 427.png, label: 0 - Pred_cdr: 0.07692307692307693
# 429.png, label: 0 - Pred_cdr: 0.07692307692307693
# 443.png, label: 0 - Pred_cdr: 0.25
# 450.png, label: 0 - Pred_cdr: 0.21428571428571427
# 454.png, label: 0 - Pred_cdr: 0.3
# 463.png, label: 0 - Pred_cdr: 1.4166666666666667
# 466.jpg, label: 0 - Pred_cdr: 0.3333333333333333
# 468.png, label: 0 - Pred_cdr: 1.0
# 470.png, label: 0 - Pred_cdr: 0.8333333333333334
# 475.png, label: 0 - Pred_cdr: 0.25
# 499.png, label: 0 - Pred_cdr: 0.3076923076923077
# 517.png, label: 0 - Pred_cdr: 0.2857142857142857
# 521.png, label: 0 - Pred_cdr: 2.6666666666666665
# 539.png, label: 0 - Pred_cdr: 0.058823529411764705
# 544.png, label: 0 - Pred_cdr: 0.75
# 546.png, label: 0 - Pred_cdr: 2.0
# 549.png, label: 0 - Pred_cdr: 0.2222222222222222
# 552.png, label: 0 - Pred_cdr: 0.21428571428571427
# 558.png, label: 0 - Pred_cdr: 0.07692307692307693
# 563.png, label: 0 - Pred_cdr: 0.75
# 567.png, label: 0 - Pred_cdr: 0.041666666666666664
# 571.png, label: 0 - Pred_cdr: 0.21428571428571427
# 58.png, label: 0 - Pred_cdr: 0.5
# 584.png, label: 0 - Pred_cdr: 0.3333333333333333
# 619.png, label: 0 - Pred_cdr: 0.5
# 621.png, label: 0 - Pred_cdr: 0.6666666666666666
# 623.png, label: 0 - Pred_cdr: 0.9166666666666666
# 633.png, label: 0 - Pred_cdr: 0.125
# 639.png, label: 0 - Pred_cdr: 0.07692307692307693
# 64.png, label: 0 - Pred_cdr: 0.6666666666666666
# 642.png, label: 0 - Pred_cdr: 0.3
# 648.png, label: 0 - Pred_cdr: 0.4166666666666667
# 651.png, label: 0 - Pred_cdr: 0.25
# 652.png, label: 0 - Pred_cdr: 1.0
# 654.png, label: 0 - Pred_cdr: 0.05263157894736842
# 655.png, label: 0 - Pred_cdr: 0.08333333333333333
# 660.png, label: 0 - Pred_cdr: 0.047619047619047616
# 669.png, label: 0 - Pred_cdr: 1.0
# 67.png, label: 0 - Pred_cdr: 0.13333333333333333
# 672.png, label: 0 - Pred_cdr: 0.11764705882352941
# 68.png, label: 0 - Pred_cdr: 0.1
# 683.png, label: 0 - Pred_cdr: 0.1
# 693.png, label: 0 - Pred_cdr: 2.0
# 71.png, label: 0 - Pred_cdr: 0.42857142857142855
# 714.png, label: 0 - Pred_cdr: 0.3333333333333333
# 721.png, label: 0 - Pred_cdr: 0.2857142857142857
# 763.png, label: 0 - Pred_cdr: 0.11764705882352941
# 77.png, label: 0 - Pred_cdr: 0.3333333333333333
# 84.png, label: 0 - Pred_cdr: 0.047619047619047616
# 87.png, label: 0 - Pred_cdr: 0.14285714285714285
# drishtiGS_035.png, label: 0 - Pred_cdr: 0.3333333333333333
# drishtiGS_037.png, label: 0 - Pred_cdr: 0.04081632653061224
# drishtiGS_041.png, label: 0 - Pred_cdr: 0.2857142857142857
# image_013.jpg, label: 0 - Pred_cdr: 1.1428571428571428
# image_052.jpg, label: 0 - Pred_cdr: 0.05263157894736842
# image_084.jpg, label: 0 - Pred_cdr: 1.2222222222222223
# image_086.jpg, label: 0 - Pred_cdr: 1.0
# image_101.jpg, label: 0 - Pred_cdr: 0.0625
# image_105.jpg, label: 0 - Pred_cdr: 0.058823529411764705
# image_110.jpg, label: 0 - Pred_cdr: 4.0
# image_129.jpg, label: 0 - Pred_cdr: 0.6666666666666666
# image_134.jpg, label: 0 - Pred_cdr: 0.13333333333333333
# image_144.jpg, label: 0 - Pred_cdr: 0.058823529411764705
# image_146.jpg, label: 0 - Pred_cdr: 0.16666666666666666
# image_148.jpg, label: 0 - Pred_cdr: 0.3333333333333333
# image_149.jpg, label: 0 - Pred_cdr: 1.0
# image_155.jpg, label: 0 - Pred_cdr: 0.26666666666666666
# image_157.jpg, label: 0 - Pred_cdr: 1.0
# image_170.jpg, label: 0 - Pred_cdr: 0.35714285714285715
# image_174.jpg, label: 0 - Pred_cdr: 3.0
# image_176.jpg, label: 0 - Pred_cdr: 1.3333333333333333
# image_177.jpg, label: 0 - Pred_cdr: 1.6923076923076923
# image_185.jpg, label: 0 - Pred_cdr: 1.5384615384615385
# image_192.jpg, label: 0 - Pred_cdr: 0.05555555555555555
# image_198.jpg, label: 0 - Pred_cdr: 0.3333333333333333
# image_214.jpg, label: 0 - Pred_cdr: 0.5
# image_217.jpg, label: 0 - Pred_cdr: 1.8666666666666667
# image_218.jpg, label: 0 - Pred_cdr: 11.5
# 233.png, label: -1 - Pred_cdr: 0.3333333333333333
# 234.png, label: -1 - Pred_cdr: 1.0588235294117647
# 235.png, label: -1 - Pred_cdr: 0.10526315789473684
# 236.png, label: -1 - Pred_cdr: 0.2631578947368421
# 237.png, label: -1 - Pred_cdr: 0.6666666666666666
# 238.png, label: -1 - Pred_cdr: 3.0
# 239.png, label: -1 - Pred_cdr: 0.07142857142857142
# 240.png, label: -1 - Pred_cdr: 0.14285714285714285
# 241.png, label: -1 - Pred_cdr: 0.6666666666666666
# 242.png, label: -1 - Pred_cdr: 0.07692307692307693
# 243.png, label: -1 - Pred_cdr: 0.125
# 244.png, label: -1 - Pred_cdr: 0.3076923076923077
# 245.png, label: -1 - Pred_cdr: 0.14285714285714285
# 246.png, label: -1 - Pred_cdr: 0.06666666666666667
# 247.png, label: -1 - Pred_cdr: 0.6666666666666666
# 248.png, label: -1 - Pred_cdr: 0.5
# 249.png, label: -1 - Pred_cdr: 0.375
# 250.png, label: -1 - Pred_cdr: 0.1
# 251.png, label: -1 - Pred_cdr: 1.0588235294117647
# 252.png, label: -1 - Pred_cdr: 0.3333333333333333
# 253.png, label: -1 - Pred_cdr: 0.05
# 254.png, label: -1 - Pred_cdr: 0.375
# 255.png, label: -1 - Pred_cdr: 2.0
# 256.png, label: -1 - Pred_cdr: 1.0
# 257.png, label: -1 - Pred_cdr: 0.05555555555555555
# 258.png, label: -1 - Pred_cdr: 0.125
# 259.png, label: -1 - Pred_cdr: 0.3333333333333333
# 260.png, label: -1 - Pred_cdr: 0.045454545454545456
# 261.png, label: -1 - Pred_cdr: 0.3684210526315789
# 262.png, label: -1 - Pred_cdr: 0.3076923076923077
# 263.png, label: -1 - Pred_cdr: 1.3333333333333333
# 264.png, label: -1 - Pred_cdr: 0.05
# 265.png, label: -1 - Pred_cdr: 0.06666666666666667
# 266.png, label: -1 - Pred_cdr: 0.3076923076923077
# 267.png, label: -1 - Pred_cdr: 0.1111111111111111
# 268.png, label: -1 - Pred_cdr: 0.15384615384615385
# 269.png, label: -1 - Pred_cdr: 1.5
# 270.png, label: -1 - Pred_cdr: 0.14285714285714285
# 271.png, label: -1 - Pred_cdr: 1.0
# 272.png, label: -1 - Pred_cdr: 0.42857142857142855
# 273.png, label: -1 - Pred_cdr: 0.14285714285714285
# 274.png, label: -1 - Pred_cdr: 1.5384615384615385
# 275.png, label: -1 - Pred_cdr: 2.0
# 276.png, label: -1 - Pred_cdr: 0.05263157894736842
# 277.png, label: -1 - Pred_cdr: 1.0
# 278.png, label: -1 - Pred_cdr: 0.6666666666666666
# 279.png, label: -1 - Pred_cdr: 0.14285714285714285
# 280.png, label: -1 - Pred_cdr: 0.6666666666666666
# 281.png, label: -1 - Pred_cdr: 0.5
# 282.png, label: -1 - Pred_cdr: 2.0
# 283.png, label: -1 - Pred_cdr: 0.125
# 284.png, label: -1 - Pred_cdr: 0.0625
# 285.png, label: -1 - Pred_cdr: 0.4
# 286.png, label: -1 - Pred_cdr: 3.0
# 287.png, label: -1 - Pred_cdr: 0.05
# 288.png, label: -1 - Pred_cdr: 0.2
# 289.png, label: -1 - Pred_cdr: 0.25
